# %%
using DataFrames

df = DataFrame(
    Name = ["Alice", "Bob", "Charlie"],
    Age = [20, 21, 22],
    Score = [90, 85, 95]
)

df
# Out:
# 3×3 DataFrame
#  Row │ Name     Age    Score
#      │ String   Int64  Int64
# ─────┼───────────────────────
#    1 │ Alice       20     90
#    2 │ Bob         21     85
#    3 │ Charlie     22     95

# %%
using CSV
using DataFrames

df = DataFrame(
    Name = ["Anna", "Boris", "Dmitry"],
    Result = [75, 82, 91]
)
# Out:
# 3×2 DataFrame
#  Row │ Name    Result
#      │ String  Int64
# ─────┼────────────────
#    1 │ Anna        75
#    2 │ Boris       82
#    3 │ Dmitry      91

# %%
CSV.write("test.csv", df)
# Out:
# "test.csv"

# %%
df2 = CSV.read("test.csv", DataFrame)

df2
# Out:
# 3×2 DataFrame
#  Row │ Name     Result
#      │ String7  Int64
# ─────┼─────────────────
#    1 │ Anna         75
#    2 │ Boris        82
#    3 │ Dmitry       91
